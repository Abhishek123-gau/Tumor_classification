# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class HistopathologyCNN(nn.Module):
    def __init__(self, num_classes=2, leaky_relu_slope=0.0):
        super(HistopathologyCNN, self).__init__()

        # Conv1: 3 input channels (RGB), 32 filters, 5x5 kernel, padding=2, stride=1
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=1, padding=2)
        nn.init.normal_(self.conv1.weight, mean=0.0, std=0.0001)  # Gaussian init std=0.0001

        # Conv2: 32 input channels, 32 filters
        self.conv2 = nn.Conv2d(32, 32, kernel_size=5, stride=1, padding=2)
        nn.init.normal_(self.conv2.weight, mean=0.0, std=0.01)    # std=0.01

        # Conv3: 32 input channels, 64 filters
        self.conv3 = nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2)
        nn.init.normal_(self.conv3.weight, mean=0.0, std=0.0001)  # std=0.0001

        # Pooling layers
        self.pool_max = nn.MaxPool2d(kernel_size=3, stride=2)
        self.pool_avg = nn.AvgPool2d(kernel_size=3, stride=2)

        # Activation function (LeakyReLU or ReLU)
        if leaky_relu_slope > 0:
            self.relu = nn.LeakyReLU(negative_slope=leaky_relu_slope)
        else:
            self.relu = nn.ReLU()

        # Fully connected layers
        # Need to calculate input size for first FC layer after conv+pool
        # Assuming input size 64x64 as per your patches:
        # After conv1 + maxpool (3x3 stride 2): output size = floor((64 + 2*2 - 5)/1 + 1) = 64 conv1 output, then pool = floor((64 - 3)/2 + 1) = 31
        # Similarly for conv2 + avgpool and conv3 + avgpool, calculate final feature map size:
        # Let's compute stepwise:

        # After conv1: size remains 64x64 (padding=2 keeps size)
        # After pool_max(3x3 stride 2): floor((64-3)/2)+1 = 31

        # After conv2: size remains 31x31
        # After pool_avg(3x3 stride 2): floor((31-3)/2)+1 = 15

        # After conv3: size remains 15x15
        # After pool_avg(3x3 stride 2): floor((15-3)/2)+1 = 7

        # So final feature map size: 64 channels × 7 × 7 = 3136

        self.fc1 = nn.Linear(64 * 7 * 7, 512)  # can adjust 512 as needed
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        # Conv1 + ReLU + MaxPool
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool_max(x)

        # Conv2 + ReLU + AvgPool
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool_avg(x)

        # Conv3 + ReLU + AvgPool
        x = self.conv3(x)
        x = self.relu(x)
        x = self.pool_avg(x)

        # Flatten for FC
        x = x.view(x.size(0), -1)

        # FC layers
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)

        # Output (no softmax here since we'll use CrossEntropyLoss which applies softmax)
        return x

# %%
from PIL import Image
import numpy as np
n=0
from torchvision import transforms
def patching(img_path):
    patched=[]
    img=Image.open(img_path).convert("RGB")
    img_array=np.array(img)
    for i in range(0,img_array.shape[0],64):
        for j in range(0,img_array.shape[1],64):
            patch=img_array[i:i+64,j:j+64]
            if(patch.shape[0]==64 and patch.shape[1]==64):
                # print(f"before cpatch{patch.shape}" )
                patch = np.transpose(patch, (2, 0, 1))
                patch=torch.tensor(patch)
                
                # print(f"after patching{patch.shape}" )
                
                patched.append(patch)
    return patched

# %%
model=HistopathologyCNN()
model.load_state_dict(torch.load("breast_model_weights_20_epoch.pth",weights_only=True))
model.eval()
# Out:
# HistopathologyCNN(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool_max): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (pool_avg): AvgPool2d(kernel_size=3, stride=2, padding=0)
#   (relu): ReLU()
#   (fc1): Linear(in_features=3136, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
from torchvision import transforms
transform = transforms.ToTensor()
from PIL import Image
img1 = transform(Image.open('mean_image_benign.png').convert('RGB'))
img2 = transform(Image.open('mean_image_malignant.png').convert('RGB'))
device="cuda"
# --- Step 2: Compute mean image ---
mean_image = (img1 + img2) / 2

def output(img_path,n,mean_image=mean_image):
    output_arr=[]
    for img in patching(img_path):
        # print(img.shape)
        final_img=(img-mean_image)
        final_img = final_img.unsqueeze(0)
        # print(f"final image shape {final_img.shape}")
        
        _, predicted = torch.max(model(final_img), 1)
        print(f"predict is {model(final_img)}")
        output_arr.append(predicted.cpu().numpy())
    total_sum = sum(output_arr)
    if((total_sum/n)>0.5):
        return 1   
    return 0

# %%
mean_image.shape
# Out:
# torch.Size([3, 64, 64])

# %%
import os
list=os.listdir("main_data/malignant")

# %%
len(list)
# Out:
# 1372

# %%
import random
random_image = random.choice(list)

# %%
random_image
n=len(patching("main_data/malignant/"+random_image))
n
# Out:
# 70

# %%
count=0
c=0
for k in range(100):
    random_image = random.choice(list)
    c=c+1
    if(output("main_data/malignant/"+random_image,n,mean_image)):
        count=count+1
    print(f"{c} image completed")

print(f"accuracy is {100-count}%")
# Out:
# predict is tensor([[ 5417.8506, -5362.0518]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5207.2583, -5151.6196]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7492.0283, -7420.7139]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6639.5903, -6570.3579]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6062.6162, -6006.1460]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5956.4927, -5901.7661]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5429.3853, -5371.0098]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4654.8271, -4609.6567]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5378.4272, -5328.2183]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5572.5483, -5512.1943]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5881.6045, -5826.9131]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5972.2876, -5904.1592]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6979.1401, -6908.9717]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5963.5620, -5902.9692]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5310.0444, -5263.5557]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5571.8608, -5519.2949]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5371.5874, -5320.7998]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5296.9097, -5252.8418]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5381.3257, -5334.4980]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6198.6196, -6138.1914]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6210.4893, -6148.6348]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4670.9175, -4621.5317]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4352.1704, -4317.9316]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4870.0303, -4829.4727]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4847.9634, -4809.3115]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5723.9556, -5668.7964]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6472.5103, -6413.8652]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5968.4067, -5909.9590]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6934.7202, -6867.6050]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7090.6958, -7029.0400]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7127.8877, -7058.3184]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5291.3062, -5245.8643]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4700.4351, -4665.9229]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4837.9595, -4797.1289]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5185.2188, -5138.5122]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5845.2441, -5791.6069]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4988.4863, -4944.3228]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5154.3257, -5116.0146]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6065.9175, -6019.8486]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6213.4756, -6168.3130]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5055.8989, -5018.4395]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3987.1411, -3965.7537]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5214.3091, -5172.0278]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5828.7661, -5776.3276]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5103.8018, -5053.6729]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6031.8228, -5979.6875]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4917.3105, -4871.1538]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5711.3130, -5654.1201]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6272.5786, -6219.4150]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5353.7788, -5315.6157]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4977.6758, -4947.5864]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5202.8965, -5150.3379]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4998.9966, -4950.2080]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5936.5874, -5876.1592]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6419.0259, -6357.8750]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7454.8955, -7386.1240]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7379.4302, -7316.8320]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5889.6333, -5846.9946]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4874.6577, -4834.3223]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5688.8032, -5624.8560]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5024.3477, -4982.9146]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5991.2261, -5928.3174]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4966.7261, -4924.6221]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4950.6309, -4907.8594]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5687.3896, -5642.2031]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5894.7710, -5839.0679]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4511.3296, -4481.4180]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4803.8062, -4756.9639]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6585.0742, -6524.3545]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5504.5073, -5462.1143]], grad_fn=<AddmmBackward0>)
# 1 image completed
# predict is tensor([[ 4483.9297, -4433.7822]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3775.2407, -3733.0725]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4215.5386, -4192.6074]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4426.9312, -4388.4512]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3816.2876, -3779.8958]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3731.5439, -3695.7297]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3859.6851, -3829.8762]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3111.9619, -3082.0476]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2633.4897, -2616.6223]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2504.5847, -2484.1565]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4900.9087, -4851.3252]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4422.8032, -4371.1895]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4769.7759, -4722.5166]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4460.9858, -4425.4814]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4168.0981, -4129.0972]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3983.4839, -3942.5281]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3764.9072, -3731.8982]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3839.6694, -3809.6931]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3494.3491, -3472.2781]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2988.0464, -2968.2842]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4867.6118, -4817.4326]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4124.9272, -4083.9231]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5431.8257, -5389.4404]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4340.8882, -4310.0967]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4528.2876, -4489.6279]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4191.7104, -4153.7393]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4379.2856, -4348.3384]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3457.7012, -3428.7200]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3799.3772, -3766.4038]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2974.2949, -2950.6326]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4055.4468, -4014.5164]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4353.7568, -4315.3936]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4501.9897, -4459.8379]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4597.0542, -4552.3018]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4712.5894, -4670.7388]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4314.2573, -4268.3979]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3786.4819, -3751.3220]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3831.3140, -3796.6130]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3988.0286, -3960.2195]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3357.1880, -3319.0457]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4103.1421, -4065.5828]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4690.6562, -4631.7090]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4248.1587, -4212.9756]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4983.7974, -4926.9883]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4492.1323, -4444.6489]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4378.3149, -4338.8428]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4148.1499, -4111.6177]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4020.3232, -3983.0491]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3768.0413, -3737.5969]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3535.8962, -3499.5884]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4116.8745, -4081.0305]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5247.7437, -5190.7466]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5414.3364, -5368.3311]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4481.6870, -4439.4019]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4533.5952, -4488.0479]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4171.6060, -4126.1494]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4047.2883, -4002.4182]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3966.0415, -3924.5942]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3952.8198, -3918.8535]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3636.6616, -3594.9299]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4040.0581, -3997.9910]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4248.0620, -4207.0317]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4445.2759, -4406.1021]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4267.9790, -4229.0488]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4189.0542, -4147.4497]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4919.2939, -4876.6445]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4237.1187, -4193.9375]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3523.6240, -3489.9666]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3790.9373, -3753.2634]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3976.5686, -3941.0461]], grad_fn=<AddmmBackward0>)
# 2 image completed
# predict is tensor([[ 7009.9917, -6936.4521]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5925.1787, -5852.9014]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5620.8086, -5550.3345]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5683.1445, -5610.3247]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6308.5835, -6228.8501]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5397.6221, -5322.4727]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6692.6372, -6620.6587]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5957.6953, -5895.5996]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6486.9321, -6410.6831]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6171.5845, -6110.2329]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5909.4370, -5854.1016]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5807.6216, -5740.5186]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5761.7080, -5693.4902]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5688.4067, -5628.9668]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7037.5068, -6959.3369]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5213.5234, -5145.2881]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6952.5327, -6881.8750]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5849.9771, -5792.0625]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6436.7173, -6358.2583]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6147.2534, -6077.0049]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5728.2173, -5659.6982]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6052.8003, -5984.0967]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5996.4731, -5929.8589]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5955.9868, -5883.1270]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7129.0796, -7051.1987]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5428.6499, -5357.3252]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6859.0986, -6778.2271]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5946.8491, -5882.5786]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6994.3228, -6919.6382]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6177.1089, -6104.4043]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5928.2378, -5860.3057]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6063.5591, -5992.1519]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5884.6934, -5816.1035]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6693.1694, -6610.5713]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7142.3604, -7062.5464]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5810.7026, -5743.5684]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6570.2549, -6484.2661]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6436.1538, -6359.6904]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5705.6050, -5648.6802]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5978.2104, -5915.9814]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6075.3228, -6012.0122]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6124.4409, -6051.4775]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5912.8521, -5847.0615]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6538.1372, -6455.7764]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6446.4531, -6374.2441]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6220.3384, -6150.7861]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6186.4336, -6109.5439]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6143.9673, -6075.9131]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6219.6812, -6147.3447]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5848.7876, -5784.9956]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5890.7407, -5828.0020]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6024.1626, -5956.1377]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5879.5786, -5816.7139]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7014.6250, -6941.0083]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6129.4116, -6055.5601]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6481.6807, -6407.5273]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5826.4780, -5754.7285]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6119.1060, -6042.5342]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6818.8042, -6742.6021]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6105.8940, -6039.5151]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5798.4663, -5737.1953]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6514.2183, -6441.8081]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6793.7017, -6717.1025]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7074.7466, -7003.6875]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5755.2729, -5682.8979]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5939.7402, -5870.1416]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6291.5576, -6220.4629]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6468.5562, -6392.3838]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6317.0293, -6247.1035]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5819.2593, -5757.4414]], grad_fn=<AddmmBackward0>)
# 3 image completed
# predict is tensor([[ 6018.0435, -5947.6221]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5668.1582, -5606.3569]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3995.3167, -3963.0886]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5971.8667, -5897.1943]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6031.1670, -5960.4463]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4044.4492, -4004.8884]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4753.7505, -4713.8457]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5895.6235, -5828.3447]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5542.2075, -5483.1421]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4884.9224, -4833.0342]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5927.6245, -5857.3867]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4856.8623, -4802.2227]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4562.7397, -4520.3867]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5682.6680, -5617.1367]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5785.0723, -5718.0840]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5524.6992, -5459.2544]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5411.8179, -5349.9854]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5147.6787, -5082.5996]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5348.1855, -5278.1836]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5445.7139, -5369.7402]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6103.0527, -6029.7183]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5371.7729, -5303.6221]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6045.2319, -5975.7329]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5742.6665, -5666.6846]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5985.0591, -5913.6367]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5369.2852, -5311.9746]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5170.3062, -5105.9160]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5517.8027, -5443.2139]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5505.9321, -5437.4810]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3950.4360, -3919.0559]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5669.0415, -5607.9849]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5947.2676, -5874.0400]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5923.1870, -5855.2065]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5568.8140, -5500.2183]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5618.1392, -5544.1543]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5644.8374, -5576.9961]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5541.4272, -5476.2739]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5798.0913, -5732.3159]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5326.1831, -5245.3359]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5287.9526, -5221.7065]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5466.4146, -5397.8438]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5634.0669, -5565.2554]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5322.0698, -5250.1616]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5718.8335, -5645.7783]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5495.6440, -5428.8984]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5366.9517, -5305.7666]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5303.3159, -5239.3477]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5635.2021, -5574.0669]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4782.2207, -4710.2109]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5610.3662, -5535.8379]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5785.5737, -5715.3481]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5583.1294, -5513.4844]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5022.1978, -4951.3130]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5683.3950, -5608.8926]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5743.0620, -5673.6479]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5525.2007, -5461.4727]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5577.2104, -5510.8018]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5837.2896, -5766.2314]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5637.3442, -5561.9917]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5680.8560, -5604.3818]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5309.4229, -5248.6533]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5649.2852, -5577.2559]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5236.0542, -5166.3403]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5191.1714, -5125.1436]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5446.6733, -5373.8203]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5935.4751, -5867.9092]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5765.4883, -5696.7896]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5900.9888, -5826.7427]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5921.4414, -5846.0986]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5988.7388, -5913.6323]], grad_fn=<AddmmBackward0>)
# 4 image completed
# predict is tensor([[ 6095.8999, -6028.5474]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6268.7358, -6199.9941]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6172.1782, -6108.0850]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6897.1548, -6816.1919]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7445.6011, -7358.6147]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7625.6602, -7530.5859]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 8156.3843, -8086.3604]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7537.1636, -7446.9082]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7913.5947, -7830.3711]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7328.2661, -7244.5151]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7412.3237, -7342.0972]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6194.1084, -6131.0684]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5727.6401, -5665.9253]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5715.5405, -5650.4492]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6921.4204, -6842.6377]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7421.4341, -7331.1035]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7791.4321, -7704.5513]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7583.2378, -7510.2764]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7172.2427, -7090.6279]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6812.6616, -6737.6440]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 8112.6284, -8044.4634]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5850.7427, -5790.5000]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5350.7485, -5302.2051]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6536.2700, -6468.1484]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6280.0835, -6211.3809]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7047.2334, -6971.1616]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7543.1499, -7461.9966]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 8361.7900, -8288.2490]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7337.3247, -7259.0176]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7131.1968, -7050.0039]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 8224.0459, -8149.4995]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5655.7676, -5599.5830]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4794.1499, -4749.3921]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6206.3550, -6145.8574]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6522.3872, -6458.4756]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6910.0640, -6845.1660]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6223.3823, -6158.3340]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6556.7769, -6489.6172]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7355.9185, -7276.1982]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6728.1807, -6661.2119]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 8073.6460, -8007.2422]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5489.3462, -5428.8296]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4921.6572, -4874.7568]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4278.9644, -4238.8281]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4322.0693, -4282.8389]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5174.3989, -5124.9307]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6199.2212, -6142.9326]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6073.2085, -6020.0337]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7172.7178, -7097.3608]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7313.4033, -7234.4443]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 8142.5923, -8067.5723]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6242.7202, -6176.8965]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4582.8647, -4536.9673]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4987.6265, -4943.7900]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4642.8296, -4600.2515]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4931.4976, -4887.9741]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5008.0044, -4961.2852]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4631.5278, -4590.4189]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5133.1216, -5085.3564]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6713.5674, -6655.7432]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 8308.9160, -8241.1807]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 8127.4014, -8064.4072]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7022.4941, -6955.5854]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6318.8306, -6252.5840]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6079.6436, -6012.0811]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5260.1675, -5200.6245]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4506.2778, -4459.4600]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4356.9438, -4318.0674]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4270.7729, -4229.6890]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5069.5454, -5019.5571]], grad_fn=<AddmmBackward0>)
# 5 image completed
# predict is tensor([[ 6419.0972, -6343.5435]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6493.6382, -6413.8794]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6203.4009, -6124.3203]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5892.0259, -5818.0527]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6290.1846, -6215.3369]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6210.3052, -6136.1733]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5918.9990, -5847.0811]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6014.5454, -5940.6543]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6326.3501, -6248.4434]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6101.5078, -6030.7832]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6386.4243, -6310.2036]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6436.9438, -6359.8071]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6103.1768, -6026.5508]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6082.2534, -6005.8877]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6110.7778, -6035.2305]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6178.5532, -6104.2686]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5908.4336, -5832.8740]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5887.6597, -5813.2656]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5945.4912, -5871.8442]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6209.3315, -6134.5425]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6451.1304, -6373.8257]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6297.7734, -6219.8940]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6133.6245, -6053.7617]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5911.8687, -5842.1689]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6370.3188, -6292.9180]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6244.2798, -6167.7622]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5750.2104, -5669.9531]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5782.2339, -5703.4263]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6019.9253, -5946.0078]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6127.5771, -6053.0874]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6564.2935, -6498.5322]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6971.4067, -6894.9624]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6660.9526, -6578.8047]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6240.4873, -6164.1406]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6436.6890, -6360.6777]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6439.0435, -6358.5996]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6343.4419, -6265.0596]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6153.7993, -6076.1670]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6238.0083, -6158.9692]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5908.5854, -5832.8687]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6348.1177, -6270.0205]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6719.7412, -6636.0459]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6742.2280, -6666.8838]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6236.1157, -6158.6753]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6499.8418, -6422.5288]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6480.6143, -6401.9272]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6326.9790, -6247.8843]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6328.4087, -6251.5498]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6364.2837, -6289.9844]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6063.6069, -5995.2896]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6552.7061, -6475.5254]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7033.0103, -6949.0259]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6549.3213, -6471.4131]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6067.6333, -5990.7559]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6357.8804, -6279.8247]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6319.4390, -6242.9473]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6309.3032, -6230.1431]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6019.5894, -5941.0991]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6207.0396, -6126.4756]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5929.2930, -5854.7671]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6587.6343, -6511.3008]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6325.7266, -6245.6006]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6431.1401, -6349.1816]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6182.0889, -6102.0371]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6058.7202, -5979.1733]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6184.3228, -6103.4170]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6006.8364, -5925.2334]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6042.6382, -5963.5591]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5883.9136, -5803.9229]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6483.7437, -6408.0659]], grad_fn=<AddmmBackward0>)
# 6 image completed
# predict is tensor([[ 5282.6685, -5219.6475]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5098.0249, -5039.4785]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5662.4917, -5598.4600]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5459.4985, -5400.8564]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5731.5571, -5663.7749]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5431.3989, -5367.3281]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5618.6177, -5553.2583]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5573.6616, -5512.1250]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5532.5742, -5468.4727]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5468.0591, -5406.6982]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5446.0425, -5385.2559]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5165.2676, -5102.7295]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5533.1992, -5467.1172]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5704.3452, -5636.7729]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5439.9976, -5376.6294]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5499.4741, -5433.6982]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5660.3140, -5593.9678]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5551.2798, -5486.8618]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5882.9487, -5819.1748]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5684.7134, -5620.5830]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5411.0659, -5347.3774]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5633.5649, -5571.8540]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5598.5972, -5531.1143]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5881.6890, -5816.5947]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5679.0645, -5610.7422]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5709.5903, -5643.8838]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5676.6919, -5613.1465]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5806.1401, -5741.8379]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5676.1040, -5615.4912]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5509.5591, -5451.2031]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5544.4976, -5483.2446]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5689.4844, -5622.7773]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5427.8940, -5367.0991]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5589.3682, -5529.4248]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5452.7935, -5385.7520]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5738.5493, -5671.7773]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5870.6001, -5800.0015]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5846.1714, -5780.7070]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5709.0503, -5649.5391]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5790.9453, -5727.5063]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5346.0420, -5286.9961]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5366.3081, -5310.3750]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5430.0591, -5368.7578]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5582.9121, -5516.2651]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5523.5684, -5466.5771]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6004.5493, -5938.7183]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5827.5532, -5766.4287]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6058.7114, -5993.7520]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6025.2739, -5963.9189]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6297.4106, -6228.2607]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5447.2041, -5377.4385]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5680.9873, -5615.1406]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5651.3916, -5590.6743]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5542.6440, -5473.4800]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5687.1455, -5618.6406]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5843.7593, -5780.0664]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5921.3516, -5854.6079]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5957.3706, -5893.6855]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5934.5171, -5868.3828]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6028.4492, -5960.5801]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5039.9517, -4982.1514]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5401.6660, -5346.4214]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5870.3120, -5800.7603]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5714.4102, -5648.6255]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5832.3667, -5771.8750]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6015.5137, -5948.1211]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6093.9902, -6035.9297]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6133.8389, -6064.9331]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6031.1758, -5963.3340]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5633.9751, -5580.5400]], grad_fn=<AddmmBackward0>)
# 7 image completed
# predict is tensor([[ 5761.8691, -5696.8369]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5667.3545, -5598.7480]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5750.6045, -5678.7407]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5698.3540, -5628.0830]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5864.0728, -5801.5020]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5872.5068, -5806.2334]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5592.0112, -5527.3584]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5878.3696, -5817.3374]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5738.7651, -5672.1060]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5890.7563, -5824.4834]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5515.9380, -5444.0933]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5581.8032, -5512.4058]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5469.1816, -5400.3643]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5569.8320, -5502.9565]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5585.7129, -5524.3286]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5803.5728, -5743.5459]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5811.4785, -5747.3242]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5786.8101, -5725.4673]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5843.0200, -5774.7969]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5776.1997, -5710.2070]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5542.0898, -5482.3833]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5682.4731, -5621.5063]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5461.7832, -5394.2471]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5946.9072, -5882.6270]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5935.2480, -5870.0049]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5807.2988, -5739.5459]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6152.9004, -6090.2861]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5843.2568, -5789.8818]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5730.2246, -5664.1831]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5586.0742, -5521.9639]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5673.5103, -5607.4092]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5747.6655, -5684.4810]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5740.8350, -5673.7749]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5472.4917, -5408.3965]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5762.7017, -5692.3350]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6020.2930, -5961.9414]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6430.4399, -6373.8887]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6000.9023, -5946.7920]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5780.9507, -5713.3198]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5812.4746, -5746.4614]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5470.7017, -5409.6396]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5723.9175, -5661.0513]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5849.3477, -5783.9502]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5945.7241, -5878.7236]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6238.3311, -6169.0718]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6021.4814, -5958.0244]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6252.5562, -6184.5352]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6394.7290, -6336.4761]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6080.0796, -6015.7075]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6004.9092, -5937.3853]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5648.8696, -5589.2769]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5866.0957, -5800.0586]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5745.7397, -5684.2246]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5861.0278, -5790.9624]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6232.1641, -6157.8447]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6081.6597, -6020.8594]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5807.3140, -5740.8770]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6588.0088, -6527.3096]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6148.6553, -6092.0098]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5473.6523, -5413.3789]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5733.8618, -5667.1289]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5892.7319, -5824.0923]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5634.9321, -5574.5571]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5789.2905, -5726.8892]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6278.3110, -6206.5938]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6087.0718, -6019.2676]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5871.8169, -5803.2354]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6035.9355, -5964.9644]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6430.8921, -6368.4521]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5674.0894, -5603.0352]], grad_fn=<AddmmBackward0>)
# 8 image completed
# predict is tensor([[ 5659.8555, -5586.6348]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5753.4917, -5683.8315]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5026.7803, -4951.0742]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4983.6270, -4908.8350]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4285.4360, -4212.0859]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5654.9883, -5578.4141]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5528.8325, -5457.1865]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4968.0923, -4895.2910]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4762.2368, -4692.5479]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5268.3315, -5195.8447]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5730.2417, -5659.7529]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5554.3716, -5482.0884]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4852.4585, -4777.0459]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5371.4292, -5295.8809]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5128.7583, -5052.4209]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5457.1089, -5387.0264]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5375.7915, -5310.0957]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4906.2144, -4831.7842]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5181.5425, -5105.8037]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5488.4990, -5417.5103]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5525.2441, -5453.3760]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5481.8706, -5406.5098]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4817.9058, -4744.1318]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5361.9380, -5297.1606]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5184.3110, -5107.2847]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5430.7261, -5361.6680]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5517.1157, -5444.7310]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5017.8276, -4945.2856]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5873.1909, -5796.9023]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5465.6538, -5388.2139]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5342.3940, -5269.1924]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5387.0786, -5315.5996]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4915.2402, -4842.8584]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5854.5830, -5781.2695]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5546.0933, -5472.7886]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5545.6123, -5470.8174]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5303.6245, -5227.9844]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5457.2368, -5383.0947]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5710.5630, -5635.0684]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5412.8569, -5338.2217]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5592.0718, -5514.3755]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5343.0298, -5269.0625]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5230.6177, -5158.7183]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5455.6104, -5383.5059]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5364.3081, -5292.7769]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5253.5259, -5177.7812]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4621.0767, -4545.4854]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5739.1870, -5664.1055]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5322.6201, -5244.9346]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5506.0508, -5428.3350]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5952.9512, -5881.2578]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5749.1792, -5677.3428]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4830.0850, -4754.9497]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5612.0337, -5543.4277]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4995.4106, -4919.5137]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5381.8525, -5309.9385]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5135.5962, -5057.1729]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5666.4312, -5591.6523]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5597.0308, -5522.2783]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5894.7476, -5821.4043]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6058.0425, -5986.0488]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5994.0933, -5922.1436]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5171.9380, -5098.4258]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5433.2573, -5369.4595]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5347.8062, -5271.6460]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4990.4648, -4914.4067]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5115.3442, -5035.3213]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5525.4106, -5446.6147]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5685.0830, -5606.7407]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5626.1802, -5547.0991]], grad_fn=<AddmmBackward0>)
# 9 image completed
# predict is tensor([[ 5247.7031, -5197.2974]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5467.0693, -5417.3770]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5667.3467, -5613.8008]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4927.9380, -4879.9277]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4581.9492, -4537.9087]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4521.4961, -4477.3486]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4310.0151, -4268.4307]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4101.6709, -4061.8215]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4478.4390, -4435.1514]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4663.3882, -4617.1826]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6684.9360, -6619.5176]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6097.2124, -6035.2202]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5269.0781, -5216.9707]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5168.5635, -5121.1357]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4584.2017, -4540.7666]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4749.8970, -4704.5693]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4320.0972, -4278.6284]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4315.4126, -4272.7603]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4461.8569, -4418.3301]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4402.1646, -4360.2285]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7783.3286, -7723.7930]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6303.3384, -6241.9180]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5161.0435, -5110.2773]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4607.5249, -4564.6846]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4826.1675, -4780.0225]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5236.3003, -5188.2485]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5267.4272, -5220.2495]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4579.9175, -4534.7725]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4731.8677, -4685.6533]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4526.5342, -4485.0649]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7612.6519, -7549.7744]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7503.7954, -7445.2656]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6931.3569, -6857.9092]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5799.5015, -5746.3857]], grad_fn=<AddmmBackward0>)
# ...
# predict is tensor([[ 4586.2056, -4531.4180]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5472.2349, -5405.1987]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3446.9524, -3399.0283]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3997.7974, -3947.1467]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3662.2490, -3615.2786]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4661.3848, -4609.5337]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6403.3384, -6330.2598]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5467.8306, -5402.2495]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3666.0620, -3613.0266]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4750.2915, -4671.6509]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6198.5200, -6105.2744]], grad_fn=<AddmmBackward0>)
# 97 image completed
# predict is tensor([[ 3400.2283, -3379.9739]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 953.7090, -988.0330]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 865.9263, -904.0931]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3863.2671, -3829.6897]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2082.6599, -2092.8621]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1539.0272, -1568.4318]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1903.6418, -1905.8021]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2044.5815, -2031.3788]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1791.1184, -1786.7408]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1997.6230, -1978.9012]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2852.7769, -2827.2756]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2389.3284, -2390.6995]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2325.0977, -2326.7380]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2022.4611, -2042.5759]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 321.0408, -377.9279]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2575.8743, -2556.2458]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2323.6743, -2307.7090]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1398.2015, -1419.6420]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1709.2649, -1710.3861]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1760.7471, -1753.9249]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2846.2522, -2852.5422]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2982.8564, -2968.5183]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2389.1130, -2389.5244]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2062.3665, -2082.0405]], grad_fn=<AddmmBackward0>)
# predict is tensor([[-98.1022,  20.5906]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2346.1619, -2368.1526]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1742.7874, -1766.8002]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 123.0523, -195.0459]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2036.1978, -2046.2356]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2252.3042, -2229.7209]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 316.7622, -392.7116]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2603.5723, -2595.3586]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2728.7339, -2719.9009]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2460.8503, -2473.0078]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2698.7417, -2695.5027]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3190.5979, -3171.7683]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3170.2773, -3144.3328]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1753.7142, -1757.4410]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2342.6499, -2332.2102]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2572.7927, -2554.5876]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 220.5830, -330.0374]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1609.6200, -1664.5387]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2583.3296, -2586.4700]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2499.4731, -2500.1272]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2722.2622, -2713.5166]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3740.6782, -3719.3909]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2299.2231, -2296.2432]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2353.4478, -2339.3679]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1356.3174, -1384.4591]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2223.9521, -2216.6824]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 235.4586, -338.6214]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 547.4063, -640.9184]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1598.6423, -1656.3435]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4131.5386, -4105.0420]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3209.5225, -3188.6985]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2939.1060, -2917.5046]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2514.0498, -2497.7134]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2537.2126, -2524.1892]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2591.1499, -2571.2747]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2984.8389, -2953.5344]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 143.5755, -254.5833]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3277.1821, -3275.1748]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3058.4663, -3044.0798]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3924.2849, -3897.8503]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2350.1873, -2383.9565]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2546.0381, -2553.0051]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1552.9443, -1606.0698]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 3714.8574, -3691.2424]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 1730.7925, -1740.9639]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 2044.5916, -2044.0646]], grad_fn=<AddmmBackward0>)
# 98 image completed
# predict is tensor([[ 5759.2568, -5679.2412]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5531.5308, -5451.4424]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5353.0537, -5273.7881]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5803.4019, -5727.1802]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5626.4790, -5547.1519]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5048.3472, -4968.2881]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5590.7637, -5518.0371]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5929.3203, -5858.3408]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5413.2075, -5341.1665]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5803.1743, -5734.9175]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5645.5420, -5569.9526]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5384.2271, -5306.2241]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5656.0239, -5580.9238]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5576.4995, -5498.9873]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5581.9106, -5502.1294]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5493.9082, -5422.6558]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5405.1899, -5345.0176]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5580.4199, -5512.2637]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5319.2168, -5240.7090]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5300.9048, -5232.6899]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5373.8960, -5300.6768]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5605.6592, -5529.1367]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5660.2661, -5586.5034]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5670.8442, -5592.1553]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5581.3154, -5511.9385]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6097.5952, -6037.8906]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5313.2378, -5248.3696]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5479.3979, -5410.2319]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5188.0811, -5111.5679]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5451.5610, -5382.0288]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5802.6255, -5724.7695]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5678.7837, -5600.5176]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5479.4849, -5399.1484]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5717.1890, -5642.6313]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5821.9277, -5750.0327]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5814.2368, -5748.7461]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5523.9204, -5452.2441]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5102.0483, -5022.5283]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4711.1445, -4639.3843]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5433.3042, -5363.9829]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5441.7407, -5371.9897]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5727.7026, -5656.4912]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5930.0942, -5868.9736]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5692.4673, -5621.8862]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5445.4512, -5373.4829]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5805.2739, -5732.6992]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5852.2090, -5786.7363]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5336.9766, -5267.7056]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5179.8652, -5112.4766]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5853.3813, -5775.7490]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5512.4087, -5438.1006]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5491.4233, -5422.1396]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5756.8584, -5693.2598]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5635.6914, -5566.2007]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5677.3638, -5601.6548]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5813.6572, -5743.5479]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6046.2554, -5978.5273]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5957.9688, -5887.3818]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5683.5044, -5620.9668]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5887.3340, -5818.0542]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5456.9819, -5388.3096]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5524.0596, -5456.9604]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5836.4575, -5772.6318]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5555.9971, -5482.0664]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5313.3804, -5236.9424]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5763.5122, -5696.8003]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6013.1079, -5946.9868]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5761.9233, -5689.5469]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5538.1958, -5466.2632]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5323.0044, -5250.1797]], grad_fn=<AddmmBackward0>)
# 99 image completed
# predict is tensor([[ 5614.8145, -5551.3828]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5468.7651, -5409.9795]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5678.4771, -5614.6572]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5245.8599, -5186.2061]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5764.0220, -5697.8633]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5567.6621, -5506.6602]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5345.8540, -5288.0508]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5355.3857, -5300.0918]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5646.4019, -5588.0283]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5276.8501, -5223.0078]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5375.7397, -5316.2354]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5656.5532, -5591.7231]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5579.4282, -5517.4053]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5598.6123, -5537.7471]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5396.8208, -5342.8232]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5409.8296, -5349.4048]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5615.8022, -5553.5820]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5685.8394, -5625.0156]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5271.4028, -5222.1611]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5144.9688, -5097.3784]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5772.6851, -5710.2983]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5543.9888, -5483.7593]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5538.6841, -5481.9102]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5720.7783, -5657.2725]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5376.8755, -5316.0449]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5315.7598, -5265.0479]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5751.1040, -5691.6313]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6181.7070, -6104.9873]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5725.0615, -5666.3633]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5586.5991, -5530.0249]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 4847.2095, -4794.7891]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5211.5298, -5159.3125]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5590.3428, -5528.1611]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5820.8560, -5752.8301]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5637.1353, -5568.3203]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5418.0835, -5350.7881]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5686.2632, -5624.9473]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5685.3506, -5619.8887]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6109.2778, -6040.4863]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5806.5830, -5744.0205]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5574.3804, -5512.6816]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5006.7622, -4957.3828]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6140.1748, -6067.7725]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5838.1602, -5771.4023]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5729.2866, -5671.1768]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5811.0835, -5738.9058]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5915.2056, -5849.4775]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5770.1831, -5699.0762]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5826.8374, -5759.7842]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5146.5630, -5091.1992]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5153.9380, -5107.9668]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5469.2827, -5416.6343]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6015.9766, -5950.2061]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5682.0693, -5621.1440]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5816.3047, -5760.4731]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5670.4702, -5618.7305]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5929.8726, -5869.2607]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5642.9624, -5580.2271]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5863.0161, -5792.5693]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5574.8950, -5508.5820]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5264.6748, -5207.3164]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6104.3052, -6028.2256]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5564.6094, -5503.7217]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5850.7856, -5782.8057]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6888.6108, -6803.6904]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 7126.8032, -7033.9087]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 6891.4067, -6805.1685]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5758.3403, -5696.0771]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5867.4634, -5802.5400]], grad_fn=<AddmmBackward0>)
# predict is tensor([[ 5308.8125, -5256.3799]], grad_fn=<AddmmBackward0>)
# 100 image completed
# accuracy is 100%

# %%
image=Image.open("1.png").convert("RGB")
image=np.array(image)
patch1 = np.transpose(image, (2, 0, 1))
img=torch.tensor(patch1)


final_img1=(img-mean_image)
final_img1= final_img1.unsqueeze(0)
model(final_img1)
# Out:
# tensor([[ 6211.7612, -6152.1997]], grad_fn=<AddmmBackward0>)
